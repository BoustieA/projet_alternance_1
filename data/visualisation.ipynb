# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("insurance.csv")

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.heatmap(df.drop(columns=["smoker","region","sex"]).corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(df,x="bmi",hue="sex",multiple="stack")
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(df,x="bmi",hue="smoker",multiple="stack")
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(df,x="bmi",hue="region",multiple="stack")
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
df.drop(columns=["smoker","region","sex"]).mean()
# Out:
# age            39.207025
# bmi            30.663397
# children        1.094918
# charges     13270.422265
# dtype: float64

# %%
df.drop(columns=["smoker","region","sex"]).std()
# Out:
# age            14.049960
# bmi             6.098187
# children        1.205493
# charges     12110.011237
# dtype: float64
